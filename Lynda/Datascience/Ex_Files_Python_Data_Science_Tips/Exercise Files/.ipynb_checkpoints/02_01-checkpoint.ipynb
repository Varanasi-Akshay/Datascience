# %%
import pandas as pd

# %%
df = pd.read_csv('data/MonthlySales.csv')

# %%
df
# Out:
#          month      sales
# 0   2013-01-01   14236.90
# 1   2013-02-01    4519.89
# 2   2013-03-01   55691.01
# 3   2013-04-01   28295.35
# 4   2013-05-01   23648.29
# 5   2013-06-01   34595.13
# 6   2013-07-01   33946.39
# 7   2013-08-01   27909.47
# 8   2013-09-01   81777.35
# 9   2013-10-01   31453.39
# 10  2013-11-01   78628.72
# 11  2013-12-01   69545.62
# 12  2014-01-01   18174.08
# 13  2014-02-01   11951.41
# 14  2014-03-01   38726.25
# 15  2014-04-01   34195.21
# 16  2014-05-01   30131.69
# 17  2014-06-01   24797.29
# 18  2014-07-01   28765.33
# 19  2014-08-01   36898.33
# 20  2014-09-01   64595.92
# 21  2014-10-01   31404.92
# 22  2014-11-01   75972.56
# 23  2014-12-01   74919.52
# 24  2015-01-01   18542.49
# 25  2015-02-01   22867.71
# 26  2015-03-01   51186.22
# 27  2015-04-01   39248.59
# 28  2015-05-01   56691.08
# 29  2015-06-01   39430.44
# 30  2015-07-01   38440.76
# 31  2015-08-01   33265.56
# 32  2015-09-01   72908.11
# 33  2015-10-01   56463.13
# 34  2015-11-01   82192.32
# 35  2015-12-01   97237.42
# 36  2016-01-01   44703.14
# 37  2016-02-01   20301.13
# 38  2016-03-01   58872.35
# 39  2016-04-01   36521.54
# 40  2016-05-01   44261.11
# 41  2016-06-01   52981.73
# 42  2016-07-01   45264.42
# 43  2016-08-01   63120.89
# 44  2016-09-01   87866.65
# 45  2016-10-01   77776.92
# 46  2016-11-01  118447.83
# 47  2016-12-01   83829.32

# %%
import json
from pandas.io.json import json_normalize

with open('data/monthlySalesbyCategoryMultiple.json') as json_data:
    d = json.load(json_data)

# %%
df = json_normalize(d['contents'], 'monthlySales', ['category', 'region'])

# %%
df
# Out:
#        month  sales    category region
# 0   20130101     38   Furniture   West
# 1   20130201     35   Furniture   West
# 2   20130301     41   Furniture   West
# 3   20130401     55   Furniture   West
# 4   20130501     58   Furniture   West
# 5   20130601     66   Furniture   West
# 6   20130701     74   Furniture   West
# 7   20130801     78   Furniture   West
# 8   20130901     38   Furniture   West
# 9   20131001     30   Furniture   West
# 10  20131101     26   Furniture   West
# 11  20131201     29   Furniture   West
# 12  20130101     54  Technology   West
# 13  20130201     66  Technology   West
# 14  20130301     77  Technology   West
# 15  20130401     70  Technology   West
# 16  20130501     60  Technology   West
# 17  20130601     63  Technology   West
# 18  20130701     55  Technology   West
# 19  20130801     47  Technology   West
# 20  20130901     55  Technology   West
# 21  20131001     30  Technology   West
# 22  20131101     22  Technology   West
# 23  20131201     77  Technology   West

# %%
#reading parquet into panda dataframe
import pyarrow.parquet as pq

# %%
table = pq.read_table('data/MonthlyProductSales.parquet')

# %%
table.to_pandas()
# Out:
#      Month of Order Date                                       Product Name  \
# 0             2017-01-13                                         Xerox 1972
# 1             2017-01-13                                         Xerox 1923
# 2             2017-01-13                                          Xerox 225
# 3             2017-01-13                                          Xerox 195
# 9243          2017-12-16                  Acco Banker's Clasps, 5 3/4"-Long
# 9244          2017-12-16  Acco 6 Outlet Guardian Premium Plus Surge Supp...
# 9245          2017-12-16                                  Acco 3-Hole Punch
# 9246          2017-12-16            #10- 4 1/8" x 9 1/2" Recycled Envelopes
# 9247          2017-12-16       14-7/8 x 11 Blue Bar Computer Printout Paper
# 9248          2017-12-16                       6" Cubicle Wall Clock, Black
# 9249          2017-12-16                   3M Hangers With Command Adhesive
# 9250          2017-12-16  3.6 Cubic Foot Counter Height Office Refrigerator
# 9251          2017-12-16                                 3-ring staple pack
#
#       Sales
# 0        11
# 1        37
# 2        19
# 3        40
# 4       756
# 5        19
# 6        11
# 7        15
# 8        25
# 9       109
# 10       56
# 11     1326
# 12       30
# 13       35
# 14      230
# 15        7
# 16      291
# 17       62
# 18      142
# 19      490
# 20      273
# 21       30
# 22        5
# 23       17
# 24       57
# 25        4
# 26      647
# 27       44
# 28      334
# 29      181
# ...     ...
# 9222     37
# 9223     30
# 9224     62
# 9225     52
# 9226      9
# 9227    302
# 9228     33
# 9229   1270
# 9230     12
# 9231     28
# 9232      9
# 9233     26
# 9234     70
# 9235      6
# 9236     13
# 9237      8
# 9238     15
# 9239     20
# 9240     18
# 9241      3
# 9242     33
# 9243     17
# 9244     29
# 9245     18
# 9246     44
# 9247     96
# 9248     10
# 9249     10
# 9250    295
# 9251      9
#
# [9252 rows x 3 columns]

# %%
# you need to install html5lib
# pip install html5lib
# reading data from a html site
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-28e6ab3d2d32> in <module>()
#       2 # pip install html5lib
#       3 # reading data from a html site
# ----> 4 df = pd.read_html('https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations')
#
# /home/akshay/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/io/html.pyc in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1092                   decimal=decimal, converters=converters, na_values=na_values,
#    1093                   keep_default_na=keep_default_na,
# -> 1094                   displayed_only=displayed_only)
#
# /home/akshay/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/io/html.pyc in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     892     retained = None
#     893     for flav in flavor:
# --> 894         parser = _parser_dispatch(flav)
#     895         p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     896
#
# /home/akshay/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/io/html.pyc in _parser_dispatch(flavor)
#     849     else:
#     850         if not _HAS_LXML:
# --> 851             raise ImportError("lxml not found, please install it")
#     852     return _valid_parsers[flavor]
#     853
#
# ImportError: lxml not found, please install it

# %%
# get part that has the states and abbreviations
df_usa = df[0]

# %%
# remove unnecessary rows and columns
final_df = df_usa.drop(df_usa.index[range(0,11)]).drop(df_usa.columns[range(10,15)], axis=1)

# %%
# rename columns
final_df.rename(columns={0: 'Region Name', 1: 'Region Status', 2: 'ISO', 3: 'ANSI_Letter', 4: 'ANSI_Code'
                         , 5: 'USPS', 6: 'USCG', 7: 'GPO', 8: 'AP', 9: 'Other Abbreviations'}, inplace=True)

# %%
# reset index of rows
final_df.reset_index(drop=True)
