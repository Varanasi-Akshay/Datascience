# %%
#Import the Pandas Module 
import pandas as pd

# %%
#Demo 1: Series  | DataFrame -> Series (attributes/functions) -> Dataframes (attributes/Functions)

# %%
# Creating a Series from a Python list 
ice_cream = ["Chocolate","Strawberry","Vanila","Rum Raisin"]

# Convert a list into series

pd.Series(ice_cream)
# Out:
# 0     Chocolate
# 1    Strawberry
# 2        Vanila
# 3    Rum Raisin
# dtype: object

# %%
lottery = [10,15 , 37 , 87 ,91,99]
lottery_s = pd.Series(lottery)
lottery_s
# Out:
# 0    10
# 1    15
# 2    37
# 3    87
# 4    91
# 5    99
# dtype: int64

# %%
#Lets try to convert a Dictionary into Series

# %%
books = {"ivorhorton":"Java7","Cogent":"BlackBook of Java","Wrox":"Python CookBook"} 
pd.Series(books)
# Out:
# ivorhorton                Java7
# Cogent        BlackBook of Java
# Wrox            Python CookBook
# dtype: object

# %%
#Introduction to Attributes (Series)

# %%
about_team = ["Brilliant","Smart","Enthusiastic","Humble","Active"]
s = pd.Series(about_team)
s
# Out:
# 0       Brilliant
# 1           Smart
# 2    Enthusiastic
# 3          Humble
# 4          Active
# dtype: object

# %%
# .values
#s.values

for item in s.values:
    if item=="abc":
        break
    print("Item => ",item)
# Out:
# Item =>  Brilliant
# Item =>  Smart
# Item =>  Enthusiastic
# Item =>  Humble
# Item =>  Active

# %%
# .index
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# .dtype
s.dtype
# Out:
# dtype('O')

# %%
# Introduction to Methods (Series)

# %%
prices = [2,10.50,7,13,32]
p = pd.Series(prices)
p
# Out:
# 0     2.0
# 1    10.5
# 2     7.0
# 3    13.0
# 4    32.0
# dtype: float64

# %%
# .sum()
p.sum()
# Out:
# 64.5

# %%
# .product()
p.product()
# Out:
# 61152.0

# %%
# .mean()
p.mean()
# Out:
# 12.9

# %%
#Parameters and Arguments
fruits=["Apple","Banana","Cherry","Strawberry","Peach","Kiwi","Orange"]
weekdays=["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"]

pd.Series(fruits,weekdays)   pd.Series
# Out:
# Sunday            Apple
# Monday           Banana
# Tuesday          Cherry
# Wednesday    Strawberry
# Thursday          Peach
# Friday             Kiwi
# Saturday         Orange
# dtype: object

# %%
#Pokemon.csv   -> Series? DataFrame?
pokemon = pd.read_csv("d:\\upgrad\\pokemon.csv",usecols=["Pokemon"],squeeze=True)
#pokemon #<Convert Series < DF  | Memory Benefit.
type(pokemon)
# Out:
# pandas.core.series.Series

# %%
# DataFrame (is the Real Hero)
# nba.csv

# %%
nba = pd.read_csv("d:\\upgrad\\nba.csv")
nba
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
# .head
nba.head(7)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0

# %%
# .tail()
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba = pd.read_csv("d:\\upgrad\\nba.csv")
nba

# %%
# Filtering Columns from a Data Frame
selected_columns=["Name","Team","College"]
nba[selected_columns].head()
# Out:
#             Name            Team            College
# 0  Avery Bradley  Boston Celtics              Texas
# 1    Jae Crowder  Boston Celtics          Marquette
# 2   John Holland  Boston Celtics  Boston University
# 3    R.J. Hunter  Boston Celtics      Georgia State
# 4  Jonas Jerebko  Boston Celtics                NaN

# %%
# Adding new Columns into DataFrame
#nba.head()
# Lets add one more columns Called Sport
#nba["Sport"]="BasketBall"
nba["Weight(KG)"]=nba["Weight"]*0.45;
nba.head()
#Weight!! Pounds > KG(s)
#add a new column weight(KG)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Sport  Weight(KG)
# 0              Texas  7730337.0  BasketBall       81.00
# 1          Marquette  6796117.0  BasketBall      105.75
# 2  Boston University        NaN  BasketBall       92.25
# 3      Georgia State  1148640.0  BasketBall       83.25
# 4                NaN  5000000.0  BasketBall      103.95

# %%
# Sorting Values
nba.sort_values(["Name"],inplace=True)
# Out:
#                     Name                    Team  Number Position   Age  \
# 152         Aaron Brooks           Chicago Bulls     0.0       PG  31.0
# 356         Aaron Gordon           Orlando Magic     0.0       PF  20.0
# 328       Aaron Harrison       Charlotte Hornets     9.0       SG  21.0
# 404        Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0
# 312           Al Horford           Atlanta Hawks    15.0        C  30.0
# 330         Al Jefferson       Charlotte Hornets    25.0        C  31.0
# 428      Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0
# 368        Alan Anderson      Washington Wizards     6.0       SG  33.0
# 135        Alan Williams            Phoenix Suns    15.0        C  23.0
# 444           Alec Burks               Utah Jazz    10.0       SG  24.0
# 128             Alex Len            Phoenix Suns    21.0        C  22.0
# 273       Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0
# ...

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Sport  Weight(KG)
# 0              Texas  7730337.0  BasketBall       81.00
# 1          Marquette  6796117.0  BasketBall      105.75
# 2  Boston University        NaN  BasketBall       92.25
# 3      Georgia State  1148640.0  BasketBall       83.25
# 4                NaN  5000000.0  BasketBall      103.95

# %%
df=  pd.read_csv("d:\\upgrad\\employees.csv",parse_dates=["Start Date","Last Login Time"])
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-05-18 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-05-18 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-05-18 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2019-05-18 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2019-05-18 16:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
#Records of Male(s)
mask = df["Gender"]=="Male"
df[mask]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2019-05-18 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2019-05-18 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2019-05-18 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2019-05-18 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2019-05-18 01:35:00  115163   10.125
# 12     Brandon   Male 1980-12-01 2019-05-18 01:08:00  112807   17.492
# 13        Gary   Male 2008-01-27 2019-05-18 23:40:00  109831    5.831
# 16      Jeremy   Male 2010-09-21 2019-05-18 05:56:00   90370    7.369
# 17       Shawn   Male 1986-12-07 2019-05-18 19:45:00  111737    6.414
# 21     Matthew   Male 1995-09-05 2019-05-18 02:12:00  100612   13.645
# 23         NaN   Male 2012-06-14 2019-05-18 16:19:00  125792    5.042
# 24        John   Male 1992-07-01 2019-05-18 22:08:00   97950   13.873
# ...

# %%
mask=df["Team"]=="Finance"
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2019-05-18 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2019-05-18 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2019-05-18 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2019-05-18 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2019-05-18 22:47:00  114796    6.796
# 53        Alan     NaN 2014-03-03 2019-05-18 13:28:00   40341   17.578
# 56        Carl    Male 2006-05-03 2019-05-18 17:55:00  130276   16.084
# 67      Rachel  Female 1999-08-16 2019-05-18 06:53:00   51178    9.735
# 68        Jose    Male 2004-10-30 2019-05-18 13:39:00   84834   14.330
# 69       Irene     NaN 2015-07-14 2019-05-18 16:31:00  100863    4.382
# 83       Shawn    Male 2005-09-23 2019-05-18 02:55:00  148115    6.539
# 84       Doris  Female 2004-08-20 2019-05-18 05:51:00   83072    7.511
# ...

# %%
#Find the Male(s) from Marketting Team

mask1 = df["Gender"]=="Male"
mask2 = df["Team"]=="Marketing"
df[mask1 & mask2]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2019-05-18 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2019-05-18 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2019-05-18 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2019-05-18 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2019-05-18 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2019-05-18 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2019-05-18 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2019-05-18 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2019-05-18 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2019-05-18 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2019-05-18 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2019-05-18 09:45:00   55281    4.935
# ...

# %%
# Can you print the Details of Team "Legal", "Sales", "Finance"   |
